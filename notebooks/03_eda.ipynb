# %% [markdown]
# # 03 — Exploratory Data Analysis

# %% [markdown]
# ## 3.1 Target construction: why price-per-sqft, not raw price

# %% [markdown]
# ## 3.2 Univariate distributions and transformations (log skew check)

# %% [markdown]
# ## 3.3 Bivariate: price vs. area, age, bedrooms

# %% [markdown]
# ## 3.4 Locality-level comparison (boxplots, ANOVA / Kruskal-Wallis)

# %% [markdown]
# ## 3.5 Temporal view: city-wide drift and seasonality

# %% [markdown]
# ## 3.6 Correlation structure and multicollinearity (VIF)

# %% [markdown]
# ## 3.7 Hypotheses carried into the next notebooks
