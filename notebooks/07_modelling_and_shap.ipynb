# %% [markdown]
# # 07 — Predictive Modelling & Explainability

# %% [markdown]
# ## 7.1 Temporal split rationale (why a random split leaks)

# %% [markdown]
# ## 7.2 OLS baseline with interpretable coefficients

# %% [markdown]
# ## 7.3 XGBoost + tuning (light, documented search space)

# %% [markdown]
# ## 7.4 Metrics: RMSE, MAE, R², MAPE — and error by cluster

# %% [markdown]
# ## 7.5 Residual spatial autocorrelation: is space fully absorbed?

# %% [markdown]
# ## 7.6 SHAP global attribution

# %% [markdown]
# ## 7.7 SHAP dependence: distance features, interaction with cluster

# %% [markdown]
# ## 7.8 Three local case studies (pre-event, post-event, amenity-poor)

# %% [markdown]
# ## 7.9 Artefact export for the FastAPI service
