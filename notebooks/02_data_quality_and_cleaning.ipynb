# %% [markdown]
# # 02 — Data Understanding & Quality

# %% [markdown]
# ## 2.1 Schema, dtypes, cardinality

# %% [markdown]
# ## 2.2 Missingness pattern analysis (MCAR / MAR reasoning, not just counts)

# %% [markdown]
# ## 2.3 Duplicate detection and resolution rule

# %% [markdown]
# ## 2.4 Unit-entry error detection (sq-m vs sq-ft)

# %% [markdown]
# ## 2.5 Geocoding failures — drop vs. impute decision

# %% [markdown]
# ## 2.6 Outlier treatment: winsorise, flag, or retain? Justify.

# %% [markdown]
# ## 2.7 Clean dataset export + before/after quality scorecard
