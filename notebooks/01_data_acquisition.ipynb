# %% [markdown]
# # 01 — Data Acquisition & Hybrid Design

# %% [markdown]
# ## 1.1 Source dataset: what it is and why this one

# %% [markdown]
# Melbourne Housing Market — real coordinates, real sale dates, real prices. Justify: most public housing data gives space OR time, not both.

# %% [markdown]
# ## 1.2 Loading and schema normalisation

# %% [markdown]
# ## 1.3 Temporal coverage check — does the window support decomposition and DiD?

# %% [markdown]
# ## 1.4 Missingness and coverage report (raw, before any cleaning)

# %% [markdown]
# ## 1.5 The hybrid design: what is real and what is synthetic

# %% [markdown]
# State the split explicitly. Five of six RQs run on real data. The synthetic overlay is confined to RQ5.

# %% [markdown]
# ## 1.6 Why a synthetic event layer — the simulation-study argument

# %% [markdown]
# Real datasets lack dated infrastructure events. Rather than drop the causal question or make an unverifiable claim, inject a known effect and measure recovery error.

# %% [markdown]
# ## 1.7 Where the overlay is applied in the pipeline, and why order matters

# %% [markdown]
# After clustering, never before. Otherwise the synthetic layer contaminates RQ1/RQ2.

# %% [markdown]
# ## 1.8 Limitations of the hybrid approach — state these up front
