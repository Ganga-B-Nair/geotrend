# %% [markdown]
# # 05 — Cluster-level Temporal Analysis

# %% [markdown]
# ## 5.1 Building per-cluster monthly series (and thin-month handling)

# %% [markdown]
# ## 5.2 STL / classical decomposition: trend, seasonal, residual

# %% [markdown]
# ## 5.3 Stationarity: ADF test per cluster, differencing decision

# %% [markdown]
# ## 5.4 ACF/PACF → ARIMA order selection

# %% [markdown]
# ## 5.5 Prophet comparison

# %% [markdown]
# ## 5.6 Rolling-origin backtest (MAPE/RMSE) — no single-split forecasting

# %% [markdown]
# ## 5.7 Forecasts with intervals, exported for the API
