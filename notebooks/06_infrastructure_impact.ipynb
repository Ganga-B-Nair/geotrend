# %% [markdown]
# # 06 — Infrastructure Impact (the centrepiece)

# %% [markdown]
# ## PART A — Correlational analysis on REAL prices

# %% [markdown]
# ## 6.1 Amenity enrichment: distances from OSM

# %% [markdown]
# ## 6.2 Distance-decay regression with property controls

# %% [markdown]
# ## 6.3 Decay by amenity type (transit vs park vs mall)

# %% [markdown]
# Everything above uses the `price` column. These are real findings and can be stated without qualification.

# %% [markdown]
# ## PART B — Simulation study on AUGMENTED prices

# %% [markdown]
# ## 6.4 Applying the event overlay to the clustered data

# %% [markdown]
# ## 6.5 Treatment and control assignment — matching on pre-period level AND slope

# %% [markdown]
# ## 6.6 Parallel trends: visual check and joint test of pre-period leads

# %% [markdown]
# If this fails, fix the control set. Do not proceed and hope nobody asks.

# %% [markdown]
# ## 6.7 Event study: lead/lag coefficient plot

# %% [markdown]
# The hero figure. Flat before the event, rising through the ramp, plateauing after.

# %% [markdown]
# ## 6.8 DiD estimation

# %% [markdown]
# ## 6.9 Standard errors: the few-clusters problem

# %% [markdown]
# Cluster-robust SEs are asymptotic in the NUMBER of clusters. With 3 treated clusters they are severely downward-biased — development runs produced SE=0.0004 on an estimate 0.019 from truth. Use wild cluster bootstrap or randomisation inference, and explain the choice.

# %% [markdown]
# ## 6.10 Robustness: placebo dates, alternative controls, noise-injected overlay

# %% [markdown]
# ## 6.11 RECOVERY TABLE — designed effect vs estimated effect vs error

# %% [markdown]
# The headline result of the project. Compare log(1+effect) against the coefficient, not raw percentages.

# %% [markdown]
# ## 6.12 What this does and does not license us to claim

# %% [markdown]
# This validates the estimator. It is not a finding about Melbourne. Say so plainly.
