# %% [markdown]
# # 04 — Spatial Dependence & Micro-neighbourhoods

# %% [markdown]
# ## 4.1 Moran's I: is price spatially autocorrelated? (I, E[I], permutation p)

# %% [markdown]
# ## 4.2 Local Moran / LISA: hot spots and cold spots

# %% [markdown]
# ## 4.3 k-distance curve → eps selection (parameter defence, not defaults)

# %% [markdown]
# ## 4.4 DBSCAN fit; noise-point handling

# %% [markdown]
# ## 4.5 Diagnostics: silhouette, cluster sizes, geographic coherence

# %% [markdown]
# ## 4.6 Folium map of micro-neighbourhoods vs. administrative localities

# %% [markdown]
# ## 4.7 External validation: same data through Weka — do clusters agree?
